# %%
# Dependencies
import numpy as np
import pandas as pd

# %%
unfilteredData = pd.read_csv('Resources/WMT.csv')
unfilteredData.head()
# Out:
#          date     open     high      low    close    volume  unadjustedVolume  \
# 0  2014-01-27  64.7650  64.9747  64.5029  64.7825   9105139           9105139
# 1  2014-01-28  64.8786  65.8746  64.7388  65.2368   6035231           6035231
# 2  2014-01-29  65.7785  65.8484  64.7126  64.7388   8440854           8440854
# 3  2014-01-30  65.1232  65.6037  64.9660  65.3067   6742046           6742046
# 4  2014-01-31  64.5816  65.6911  64.3369  65.2455  10665285          10665285
#
#      change  changePercent     vwap       label  changeOverTime
# 0 -0.235889         -0.363  64.7739  Jan 27, 14        0.000000
# 1  0.454305          0.701  65.3045  Jan 28, 14        0.007013
# 2 -0.497990         -0.763  61.0517  Jan 29, 14       -0.000675
# 3  0.567883          0.877  65.2975  Jan 30, 14        0.008092
# 4 -0.061155         -0.094  65.3223  Jan 31, 14        0.007147

# %%
unfilteredData = unfilteredData.drop(columns=["volume", "unadjustedVolume", "change", "changePercent", "vwap", "label", "changeOverTime"])
unfilteredData.head()
# Out:
#          date     open     high      low    close
# 0  2014-01-27  64.7650  64.9747  64.5029  64.7825
# 1  2014-01-28  64.8786  65.8746  64.7388  65.2368
# 2  2014-01-29  65.7785  65.8484  64.7126  64.7388
# 3  2014-01-30  65.1232  65.6037  64.9660  65.3067
# 4  2014-01-31  64.5816  65.6911  64.3369  65.2455

# %%
lastIndex = len(unfilteredData)
print(lastIndex)
# Out:
# 1259

# %%
startDate = unfilteredData.loc[unfilteredData["date"] == "2016-06-01"]
startDateIndex = startDate.index.tolist()
print(startDateIndex[0])
# Out:
# 591

# %%
filteredData = unfilteredData.loc[startDateIndex[0]:lastIndex]

# %%
filteredData.head()
# Out:
#            date     open     high      low    close
# 591  2016-06-01  65.8547  66.2330  65.7706  65.8547
# 592  2016-06-02  65.8547  66.3217  65.5231  66.2750
# 593  2016-06-03  65.9201  66.3684  65.8733  66.2003
# 594  2016-06-06  66.8075  66.8355  66.3217  66.3684
# 595  2016-06-07  66.4151  66.6113  66.1816  66.3497

# %%
filteredData.reset_index(inplace=True, drop=True)
filteredData.head()
# Out:
#          date     open     high      low    close
# 0  2016-06-01  65.8547  66.2330  65.7706  65.8547
# 1  2016-06-02  65.8547  66.3217  65.5231  66.2750
# 2  2016-06-03  65.9201  66.3684  65.8733  66.2003
# 3  2016-06-06  66.8075  66.8355  66.3217  66.3684
# 4  2016-06-07  66.4151  66.6113  66.1816  66.3497

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import autocorrelation_plot
color = sns.color_palette()
from statsmodels.tsa.arima_model import ARIMA
from pandas import datetime
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score

# %%
def parser(x):
    return datetime.strptime(x, '%Y-%m')

# %%
print("please wait. importing...")
data = pd.read_csv("Resources/WMT.csv")

print("importing finished.")
data

# data['Total_Price'] = data['Quantity']*data['UnitPrice']

# data = data[data.Quantity > 0]
# data = data[data.UnitPrice > 0]
# data = data[data.iloc[:, :] != '']
# Out:
# please wait. importing...
# importing finished.
#             date     open     high      low    close    volume  \
# 0     2014-01-27  64.7650  64.9747  64.5029  64.7825   9105139
# 1     2014-01-28  64.8786  65.8746  64.7388  65.2368   6035231
# 2     2014-01-29  65.7785  65.8484  64.7126  64.7388   8440854
# 3     2014-01-30  65.1232  65.6037  64.9660  65.3067   6742046
# 4     2014-01-31  64.5816  65.6911  64.3369  65.2455  10665285
# 1243           8277289 -0.480000         -0.514  93.6598       Jan 3
# 1244           8029144  0.580000          0.625  93.2346       Jan 4
# 1245           7789701  1.100000          1.177  94.5647       Jan 7
# 1246           7200912  0.660000          0.698  95.0263       Jan 8
# 1247           6272293 -0.310000         -0.326  95.3602       Jan 9
# 1248           9396271  0.070000          0.074  94.4584      Jan 10
# 1249           5394592 -0.120000         -0.126  94.8912      Jan 11
# 1250           7085094  0.110000          0.116  95.0168      Jan 14
# 1251           7058230  1.300000          1.369  96.0915      Jan 15
# 1252           5409950  0.100000          0.104  96.3172      Jan 16
# 1253           5614489  0.390000          0.405  96.6549      Jan 17
# 1254           6120643  0.990000          1.023  97.5274      Jan 18
# 1255           8063202 -0.240000         -0.246  97.6006      Jan 22
# 1256           8345750  1.220000          1.251  98.5121      Jan 23
# 1257           7609746 -0.350000         -0.355  97.8649      Jan 24
# 1258           7222089 -1.420000         -1.444  97.2279      Jan 25
#
#       changeOverTime
# 0           0.000000
# 1           0.007013
# 2          -0.000675
# 3           0.008092
# 4           0.007147
# 5          -0.020095
# 6          -0.019150
# 7          -0.017262
# 8          -0.017937
# 9          -0.005395
# 10         -0.005259
# 11          0.008766
# 12          0.010924
# 13          0.016318
# 14          0.022117
# 15          0.015913
# 16          0.009441
# 17         -0.008496
# 18         -0.013891
# 19         -0.010788
# 20         -0.010788
# 21          0.008496
# 22          0.005529
# 23          0.007417
# 24         -0.000404
# 25          0.013217
# 26          0.008766
# 27          0.009845
# 28          0.012287
# 29          0.010251
# ...              ...
# 1229        0.437271
# 1230        0.434955
# 1231        0.417821
# 1232        0.401150
# 1233        0.405935
# 1234        0.397754
# 1235        0.347277
# 1236        0.344962
# 1237        0.324740
# 1238        0.395593
# 1239        0.413808
# 1240        0.422143
# 1241        0.437888
# 1242        0.440821
# 1243        0.433412
# 1244        0.442365
# 1245        0.459345
# 1246        0.469533
# 1247        0.464747
# 1248        0.465828
# 1249        0.463976
# 1250        0.465674
# 1251        0.485741
# 1252        0.487284
# 1253        0.493305
# 1254        0.508586
# 1255        0.504882
# 1256        0.523714
# 1257        0.518311
# 1258        0.496392
#
# [1259 rows x 12 columns]

# %%
#data['date'] = data['InvoiceDate'].map(lambda x: str(x)[:7])

# %%
#print(data)
Quantity_date=data[['date', 'Quantity']].drop_duplicates()
Quantity_date_count=Quantity_date.groupby(['date'])['Quantity'].aggregate('sum').reset_index().sort_values(by='date', ascending=0)

# %%
date=list(Quantity_date_count['date'])
quantity=list(Quantity_date_count['Quantity'])
date_quantity = pd.DataFrame({'dates': date, 'quantity':quantity})
#date_quantity['quantity'] = date_quantity['quantity'].map(lambda x: str(x))

# %%
date_quantity.index = date_quantity['dates'].map(lambda x: parser(x))
date_quantity['quantity'] = date_quantity['quantity'].map(lambda x: float(x))

# %%
date_quantity = date_quantity.fillna(date_quantity.bfill())
date_quantity = date_quantity['quantity'].resample('MS').mean()
print(date_quantity)
date_quantity.plot()
plt.show()

# %%
autocorrelation_plot(date_quantity)
plt.show()

# %%
quantity = date_quantity.values

# %%
size = int(len(quantity) * 0.66)
train, test = quantity[0:size], quantity[size:len(quantity)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(2 ,2 ,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat[0])
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))

# %%
pred = np.array(predictions)

# %%
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)

# %%
# plot
plt.plot(test)
plt.plot(predictions, color='red')
plt.show()
